# %%
import requests
import pandas as pd
import numpy as np

# %%
remote_url = 'https://data.gov.spb.ru/opendata/123/versions/21/csv/'
data = requests.get(remote_url)

# %% [markdown]
# **Музеи Санкт-Петербурга**

# %%
df = pd.read_csv('/content/drive/MyDrive/data-20210316T134141-structure-20200803T115911.csv')
df
# Out:
#        oid                                      name  ...           ogrn         inn
# 0     3285                            Аничков Дворец  ...  2147483647123  7840325991
# 1     3287       Воскресенский Новодевичий монастырь  ...  1037858002698  7810387493
# 2     3290                          Музей Дома Радио  ...            NaN         NaN
# 3     3295                             Зимний дворец  ...  1037843031808  7830002416
# 4     3296       Смольный институт благородных девиц  ...  1047844026933  7825453621
# ..     ...                                       ...  ...            ...         ...
# 250  18260  Санкт-Петербургский художественный музей  ...            NaN         NaN
# 251  18394                            Музей матрёшки  ...            NaN         NaN
# 252  18464                                  Титикака  ...            NaN         NaN
# 253  18465                        МузЭрос Pinkrabbit  ...            NaN         NaN
# ...

# %% [markdown]
# *Общее количество музеев*

# %%
df.shape
# Out:
# (255, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 255 entries, 0 to 254
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   oid             255 non-null    int16
#  1   name            255 non-null    category
#  2   name_en         231 non-null    category
#  3   type            253 non-null    category
#  4   country         255 non-null    category
#  5   address_manual  255 non-null    category
#  6   district        248 non-null    category
#  7   phone           255 non-null    category
#  8   www             255 non-null    category
#  9   email           245 non-null    category
#  10  description     237 non-null    category
#  11  description_en  216 non-null    category
#  12  work_time       245 non-null    category
#  13  for_disabled    255 non-null    int8
#  14  coord           255 non-null    category
#  15  ogrn            220 non-null    category
# ...

# %% [markdown]
# Очевидно, что есть пропуски значений

# %% [markdown]
# *Распределение музеев по районам СПб*

# %%
df['district'].value_counts()
# Out:
# Центральный          79
# Адмиралтейский       35
# Василеостровский     31
# Петроградский        30
# Пушкинский           10
# Приморский            9
# Невский               8
# Московский            8
# Выборгский            8
# Кировский             6
# Калининский           6
# Петродворцовый        4
# Красногвардейский     4
# Фрунзенский           3
# Курортный             2
# Колпинский            2
# Кронштадтский         2
# Красносельский        1
# Name: district, dtype: int64

# %% [markdown]
# *Распределение музеев по типам*

# %%
df['type'].value_counts()
# Out:
# ведомственное учреждение                                      43
# частный                                                       31
# федеральные (ведомственные)                                   31
# федеральные (Министерство Культуры РФ)                        28
# Городские (комитет по культуре)                               27
# гос. федеральное учреждение                                   19
# гос.федеральное учреждение                                    15
# районные                                                       9
# городское (комитет по культуре) государственное учреждение     6
# государственное федеральное (ведомственное) учреждение         5
# негосударственное учреждение                                   5
# филиал                                                         3
# городские (комитет по культуре)                                3
# федеральное (ведомственное) государственное учреждение         3
# ...
